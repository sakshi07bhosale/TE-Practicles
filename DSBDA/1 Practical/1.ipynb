# %%
import pandas as pd
import numpy as np

# %%
dt = pd.read_csv("vehicles.csv", sep=";")  # or '\t' for tab‑separated

# %%
print(dt)
# Out:
#     Make,Model,Year,Engine Size (L),Fuel Type,Price
# 0              Toyota,Corolla,2018,1.8,Petrol,15000
# 1                 Honda,Civic,2019,2.0,Petrol,17000
# 2                  Ford,Focus,2017,1.5,Diesel,14000
# 3             Hyundai,Elantra,2020,2.0,Petrol,18000
# 4            Chevrolet,Malibu,2016,2.5,Petrol,13500
# ..                                              ...
# 145                    BMW,X6,2018,3.0,Petrol,80000
# 146           Mercedes,GLS400,2019,3.0,Petrol,90000
# 147                   Audi,Q8,2017,3.0,Petrol,95000
# 148              Lexus,UX250h,2020,2.0,Hybrid,60000
# 149              Jeep,Compass,2018,2.0,Diesel,25000
#
# [150 rows x 1 columns]

# %%
ct = dt.columns

# %%
print(ct)
# Out:
# Index(['Make,Model,Year,Engine Size (L),Fuel Type,Price'], dtype='object')

# %%
st=dt.shape

# %%
print(st)
# Out:
# (150, 1)

# %%
cv=dt.columns.values

# %%
print(cv)
# Out:
# ['Make,Model,Year,Engine Size (L),Fuel Type,Price']

# %%
dt.describe()
# Out:
#        Make,Model,Year,Engine Size (L),Fuel Type,Price
# count                                              150
# unique                                             150
# top               Toyota,Corolla,2018,1.8,Petrol,15000
# freq                                                 1

# %%
dt.describe(include='all')
# Out:
#        Make,Model,Year,Engine Size (L),Fuel Type,Price
# count                                              150
# unique                                             150
# top               Toyota,Corolla,2018,1.8,Petrol,15000
# freq                                                 1

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 dt[['Model']]
#
# File c:\Users\hp\anaconda3\Lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\hp\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# ...
