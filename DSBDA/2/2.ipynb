# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv('./student_scores.csv')

# %%
print(df)
# Out:
#     math score  reading score  writing score  placement score  \
# 0           85             90             88               92
# 1           78             82             80               85
# 2           92             95             94               98
# 3           70             75             72               78
# 4           88             87             90               91
# 5           65             68             70               72
# 6           80             85             83               88
# 7           77             79             78               80
# 8           95             97             96               99
# 9           60             62             65               68
# 10          83             86             85               89
# 11          74             78             76               80
# 12          90             92             91               95
# 13          68             70             72               74
# ...

# %%
df.isnull()
# Out:
#     math score  reading score  writing score  placement score  \
# 0        False          False          False            False
# 1        False          False          False            False
# 2        False          False          False            False
# 3        False          False          False            False
# 4        False          False          False            False
# 5        False          False          False            False
# 6        False          False          False            False
# 7        False          False          False            False
# 8        False          False          False            False
# 9        False          False          False            False
# 10       False          False          False            False
# 11       False          False          False            False
# 12       False          False          False            False
# 13       False          False          False            False
# ...

# %%
s=pd.isna(df['placement score'])

# %%
print(s)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# Name: placement score, dtype: bool

# %%
s=pd.isnull(df['placement score'])

# %%
print(s)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# Name: placement score, dtype: bool

# %%
ndf=df

# %%
ndf.fillna(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 ndf.fillna(3)
#
# NameError: name 'ndf' is not defined

# %%
nv=df['math score'].mean()
df['math score']=df['math score'].fillna(value=nv)
df
# Out:
#     math score  reading score  writing score  placement score  \
# 0           85             90             88               92
# 1           78             82             80               85
# 2           92             95             94               98
# 3           70             75             72               78
# 4           88             87             90               91
# 5           65             68             70               72
# 6           80             85             83               88
# 7           77             79             78               80
# 8           95             97             96               99
# 9           60             62             65               68
# 10          83             86             85               89
# 11          74             78             76               80
# 12          90             92             91               95
# 13          68             70             72               74
# ...

# %%
ndf.replace(to_replace=np.nan,value=-99)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 ndf.replace(to_replace=np.nan,value=-99)
#
# NameError: name 'ndf' is not defined

# %%
ndf.dropna(axis=0,how='any')
# Out:
#     math score  reading score  writing score  placement score  \
# 0           85             90             88               92
# 1           78             82             80               85
# 2           92             95             94               98
# 3           70             75             72               78
# 4           88             87             90               91
# 5           65             68             70               72
# 6           80             85             83               88
# 7           77             79             78               80
# 8           95             97             96               99
# 9           60             62             65               68
# 10          83             86             85               89
# 11          74             78             76               80
# 12          90             92             91               95
# 13          68             70             72               74
# ...

# %%
df.isnull()
# Out:
#     math score  reading score  writing score  placement score  \
# 0        False          False          False            False
# 1        False          False          False            False
# 2        False          False          False            False
# 3        False          False          False            False
# 4        False          False          False            False
# 5        False          False          False            False
# 6        False          False          False            False
# 7        False          False          False            False
# 8        False          False          False            False
# 9        False          False          False            False
# 10       False          False          False            False
# 11       False          False          False            False
# 12       False          False          False            False
# 13       False          False          False            False
# ...

# %%
ndf.dropna(axis=0,how='all')
# Out:
#     math score  reading score  writing score  placement score  \
# 0           85             90             88               92
# 1           78             82             80               85
# 2           92             95             94               98
# 3           70             75             72               78
# 4           88             87             90               91
# 5           65             68             70               72
# 6           80             85             83               88
# 7           77             79             78               80
# 8           95             97             96               99
# 9           60             62             65               68
# 10          83             86             85               89
# 11          74             78             76               80
# 12          90             92             91               95
# 13          68             70             72               74
# ...

# %%
r=pd.notnull(df['club join years'])

# %%
df[r]
# Out:
#     math score  reading score  writing score  placement score  \
# 0           85             90             88               92
# 1           78             82             80               85
# 2           92             95             94               98
# 3           70             75             72               78
# 4           88             87             90               91
# 5           65             68             70               72
# 6           80             85             83               88
# 7           77             79             78               80
# 8           95             97             96               99
# 9           60             62             65               68
# 10          83             86             85               89
# 11          74             78             76               80
# 12          90             92             91               95
# 13          68             70             72               74
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['math score']=le.fit_transform(df['math score'])

# %%
df['math score']=le.fit_transform(df['math score'])

# %%
newdf=df

# %%
df
# Out:
#     math score  reading score  writing score  placement score  \
# 0           19             90             88               92
# 1           12             82             80               85
# 2           26             95             94               98
# 3            6             75             72               78
# 4           22             87             90               91
# 5            2             68             70               72
# 6           14             85             83               88
# 7           11             79             78               80
# 8           29             97             96               99
# 9            0             62             65               68
# 10          17             86             85               89
# 11           8             78             76               80
# 12          24             92             91               95
# 13           5             70             72               74
# ...

# %%
col=['math score','reading score','writing score','placement score']

# %%
df.boxplot(col)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# %%
fig,ax=plt.subplots(figsize=(18,10))
ax.scatter(df['placement score'], df['placement offers'])
plt.show()
ax.set_xlabel('(proportion non retail business acres)/(towe)')
ax.set_ylabel('(full value property tax rate)/($10,000)')
print(np.where((df['placement score']<50)& (df['placement offers']>1)))
print(np.where((df['placement score']<85)& (df['placement offers']<3)))
# Out:
# (array([], dtype=int64),)
# (array([ 3,  5,  7,  9, 11, 13, 16, 18, 20, 22, 26, 28]),)

# %%
from scipy import stats

# %%
z=np.abs(stats.zscore(df['math score']))

# %%
print(z)
# Out:
# [0.51990416 0.28883564 1.32864396 0.98204119 0.86650693 1.44417822
#  0.05776713 0.4043699  1.67524673 1.67524673 0.28883564 0.75097267
#  1.09757545 1.09757545 0.63543842 0.05776713 0.86650693 0.98204119
#  1.2131097  0.4043699  0.51990416 1.44417822 1.55971247 0.75097267
#  0.17330139 1.2131097  1.32864396 0.17330139 0.63543842 1.55971247]

# %%
threshold=1

# %%
so=np.where(z>threshold)

# %%
print(so)
# Out:
# (array([ 2,  5,  8,  9, 12, 13, 18, 21, 22, 25, 26, 29]),)
