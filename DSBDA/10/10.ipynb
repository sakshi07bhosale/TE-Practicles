# %%
from sklearn.datasets import load_iris
import pandas as pd 
iris=load_iris()

# %%
db=pd.DataFrame(data=iris.data,columns=iris.feature_names)
db['target']=iris.target
db.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
name = ['sepal_length','sepal_width','petal_length','petal_width','class']
iris = pd.read_csv(url, names=name)

# %%
print("features and their types:")
print(iris.dtypes)
# Out:
# features and their types:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# class               str
# dtype: object

# %%
iris.hist(figsize=(10,6))
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=iris.drop(columns='class'))
plt.show()
