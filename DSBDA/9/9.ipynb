# %%
import matplotlib.pyplot as plt 
import seaborn as sb 
db=sb.load_dataset('titanic')
db.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sb.boxplot(x='sex',y='age',data=db)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sb.boxplot(x='sex',y='age',data=db,hue='survived')
plt.show()

# %%
db['survived'].value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
mean=db['age'].mean()

# %%
mean
# Out:
# np.float64(29.69911764705882)

# %%
std=db['age'].std()
std
# Out:
# np.float64(14.526497332334042)

# %%
sb.heatmap(db.isnull(),cmap='viridis',cbar=False)
plt.show()

# %%
sb.countplot(data=db,x="survived",hue="alive")
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
from enum import auto
explode=[0,0]
db['survived'].value_counts().plot.pie(autopct='%.2f%%',explode=explode)
# Out:
# <Axes: >

# %%
from ctypes import pointer
sb.catplot(x='pclass',y='survived',data=db,kind='point')

# %%
sb.catplot(x='sex',y='fare',data=db,kind='boxen')

# %%
sb.catplot(X='sex',y='age',data=db)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 sb.catplot(X='sex',y='age',data=db)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\seaborn\categorical.py:2879, in catplot(data, x, y, hue, row, col, kind, estimator, errorbar, n_boot, seed, units, weights, order, hue_order, row_order, col_order, col_wrap, height, aspect, log_scale, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    2876     if "s" not in plot_kws:
#    2877         plot_kws["s"] = plot_kws.pop("size", 5) ** 2
# -> 2879     p.plot_strips(
#    2880         jitter=jitter,
#    2881         dodge=dodge,
#    2882         color=color,
#    2883         plot_kws=plot_kws,
#    2884     )
#    2886 elif kind == "swarm":
#    2888     warn_thresh = kwargs.pop("warn_thresh", .05)
#
# ...
